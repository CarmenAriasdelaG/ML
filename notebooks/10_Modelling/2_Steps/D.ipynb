# %%
import plotly.express as px
df = px.data.tips()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df["tip"]

# %%
X = df.drop(columns= "tip")

# %%
X_reg = df[["size", "total_bill"]]

# %%
X_reg_sim = df[["total_bill"]]

# %%
model.fit(X_reg_sim, y)
# Out:
# LinearRegression()

# %%
model.score(X_reg_sim, y)
# Out:
# 0.45661658635167657

# %%
model.predict(X=[[33]])
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.38607869])

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_reg, y)
# Out:
# LinearRegression()

# %%
model.score(X_reg, y)
# Out:
# 0.46786930879612576

# %%
model.predict(X=[[4, 33]])
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.49887603])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Algoritmo

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_rf = RandomForestRegressor()

# %%
model_rf
# Out:
# RandomForestRegressor()

# %%
model_rf.fit(X_reg,y)
# Out:
# RandomForestRegressor()

# %%
model_rf.score(X_reg,y)
# Out:
# 0.8940157417434371

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_tree = DecisionTreeRegressor()
model_tree
# Out:
# DecisionTreeRegressor()

# %%
model_tree.fit(X_reg, y)
# Out:
# DecisionTreeRegressor()

# %%
model_tree.predict(X=[[4, 33]])
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([6.])

# %%
model_tree.score(X_reg, y)
# Out:
# 0.9937824826087782

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model_kn = KNeighborsRegressor()
model_kn
# Out:
# KNeighborsRegressor()

# %%
model_kn.fit(X_reg, y)
# Out:
# KNeighborsRegressor()

# %%
model_kn.score(X_reg, y)
# Out:
# 0.5679457239089669

# %%
model_kn.predict(X=[[4, 33]])
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([4.91])

# %%
from sklearn.svm import SVR

# %%
model_svr = SVR(C = 0.1)
model_svr
# Out:
# SVR(C=0.1)

# %%
model_svr.fit(X_reg, y)
# Out:
# SVR(C=0.1)

# %%
model_svr.score(X_reg, y)
# Out:
# 0.35155368413001753

# %%
SVR?
# Out:
# Init signature:
# SVR(
#     *,
#     kernel='rbf',
#     degree=3,
#     gamma='scale',
#     coef0=0.0,
#     tol=0.001,
#     C=1.0,
#     epsilon=0.1,
#     shrinking=True,
#     cache_size=200,
#     verbose=False,
#     max_iter=-1,
# )
# Docstring:
# Epsilon-Support Vector Regression.
#
# The free parameters in the model are C and epsilon.
#
# The implementation is based on libsvm. The fit time complexity
# is more than quadratic with the number of samples which makes it hard
# to scale to datasets with more than a couple of 10000 samples. For large
# datasets consider using :class:`~sklearn.svm.LinearSVR` or
# :class:`~sklearn.linear_model.SGDRegressor` instead, possibly after a
# :class:`~sklearn.kernel_approximation.Nystroem` transformer or
# other :ref:`kernel_approximation`.
#
# Read more in the :ref:`User Guide <svm_regression>`.
#
# Parameters
# ----------
# kernel : {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'} or callable,          default='rbf'
# ...
